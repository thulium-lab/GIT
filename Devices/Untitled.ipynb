# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import time
import importlib
import wlm
import matplotlib.animation as animation

# %%
import ctypes

# %%
importlib.reload(wlm)
# Out:
# <module 'wlm' from 'D:\\!Data\\GIT\\Devices\\wlm.py'>

# %%
wlm0 = wlm.WavelengthMeter()

# %%
wlm0.wavelength
# Out:
# 1061.6883850503993

# %%
wlm0.wavelength_air()
# Out:
# 1061.6883852209014
# 1061.3976957220048

# %%
setter = wlm0.dll.SetPattern
setter.restype = ctypes.c_long
# print('setter 1,1\t',setter(ctypes.c_long(1),ctypes.c_long(1)))
size,length,adress = (wlm0.dll.GetPatternItemSize(ctypes.c_long(1)), wlm0.dll.GetPatternItemCount(ctypes.c_long(1)),
                wlm0.dll.GetPattern(ctypes.c_long(1)))
#print(size,length,adress)
mem = ctypes.c_int*length
b = ctypes.cast(adress,ctypes.POINTER(mem))

# %%
res = []
res.append([b.contents[i] for i in range(0,length)])

# %%
print(wlm0.wavelength)
print(wlm0.power)
print(wlm0.amplitudes)
b = wlm0.spectrum
print(len(b))
print(wlm0.exposure)
# Out:
# 1104.0511103842014
# 136577024
# (713, 1756)
# 2
# 23

# %%
wm_data = {'wavelength':wlm0.wavelength,
                           'amplitudes':wlm0.amplitudes,
                           'spectrum': wlm0.spectrum
                           }
print(wm_data['wavelength'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-bb0e2f481385> in <module>()
#       1 wm_data = {'wavelength':wlm0.wavelength,
#       2                            'amplitudes':wlm0.amplitudes,
# ----> 3                            'spectrum': wlm0.spectrum
#       4                            }
#       5 print(wm_data['wavelength'])
#
# D:\!Data\GIT\Devices\wlm.py in spectrum(self)
#      83         b = ctypes.cast(adress,ctypes.POINTER(mem))
#      84         res = []
# ---> 85         res.append([b.contents[i] for i in range(0,length)])
#      86
#      87         #print('setter 0,1\t',setter(ctypes.c_long(0),ctypes.c_long(1)))
#
# D:\!Data\GIT\Devices\wlm.py in <listcomp>(.0)
#      83         b = ctypes.cast(adress,ctypes.POINTER(mem))
#      84         res = []
# ---> 85         res.append([b.contents[i] for i in range(0,length)])
#      86
# ...

# %%
1061.68841 / 1061.39773
# Out:
# 1.0002738652927023

# %%
import pyqtgraph.examples
pyqtgraph.examples.run()

# %%
# %%timeit 
b = wlm0.spectrum
# print(wlm0.wavelength)
# Out:
# 1000 loops, best of 3: 666 µs per loop

# %%
fig,ax = subplots(2)
ax[0].plot(b[1][:1024],lw='.4')
ax[0].set_xlim(0,1024)
ax[0].grid()
ax[1].plot(b[0][:1024],lw='.4')
ax[1].set_xlim(0,1024)
ax[1].grid()
print(wlm0.wavelength)
# Out:
# -3.0

# %%
def init():
    ax.set_ylim(0, 1e8)
    ax.set_xlim(0, 1024)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(*argv,**argd):
    # update the data
    b = wlm0.spectrum
    print(len(b))
    xdata = arange(1024)
    ydata = arange(b[0][:1024])
    ymin = 0
    ymax = max(ydata)*1.1

    ax.set_ylim(ymin, xmax)
    ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, frames=10, blit=False, interval=1000, init_func=init)
ani
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\program files\anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# c:\program files\anaconda\lib\site-packages\matplotlib\animation.py in _repr_html_(self)
#     979         fmt = rcParams['animation.html']
#     980         if fmt == 'html5':
# --> 981             return self.to_html5_video()
#     982
#     983
#
# c:\program files\anaconda\lib\site-packages\matplotlib\animation.py in to_html5_video(self)
#     949                 # We create a writer manually so that we can get the
#     950                 # appropriate size for the tag
# ...

# %%
from matplotlib import rc, animation
rc('animation', html='html5')

# %%
def update_line(num, data, line):
    line.set_data(data[..., :num])
    return line,

fig1 = plt.figure()

data = np.random.rand(2, 25)
l, = plt.plot([], [], 'r-')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel('x')
plt.title('test')
line_ani = animation.FuncAnimation(fig1, update_line, 25, fargs=(data, l),
                                   interval=50, blit=True)
line_ani
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\program files\anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# c:\program files\anaconda\lib\site-packages\matplotlib\animation.py in _repr_html_(self)
#     979         fmt = rcParams['animation.html']
#     980         if fmt == 'html5':
# --> 981             return self.to_html5_video()
#     982
#     983
#
# c:\program files\anaconda\lib\site-packages\matplotlib\animation.py in to_html5_video(self)
#     949                 # We create a writer manually so that we can get the
#     950                 # appropriate size for the tag
# ...

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
plt.ion()
fig,ax = subplots()
line1, = ax.plot(array(b[1][:1024]))
plt.pause(0.1)
plt.show()
for i in range(5):
    line1.set_ydata(array(b[1][:1024])*(i+1))
    fig.canvas.draw()
#     show()
#     time.sleep(1)
#     plt.show()
    plt.pause(0.1)

# %%
ax.lines.clear()

# %%
plot(b[1]

# %%
bb = [d.contents[i] f]
# Out:
# 2162723

# %%
wlm0.temperature
# Out:
# 26.77420000000368

# %%
a = 4

print(tan(a*pi/180) * 200)
print(tan(a*pi/180) * 350)
print(tan(a*pi/180) * 400)
print(tan(a*pi/180) * 500)
print(tan(a*pi/180) * 700)
# Out:
# 13.9853623887
# 24.4743841802
# 27.9707247774
# 34.9634059718
# 48.9487683605

# %%
pi/180
# Out:
# 0.017453292519943295
